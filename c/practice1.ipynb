# %%
message = []
messages = []
user_input = input("enter: ")

# %%
message = {
    "role": "user",
    "content":[{
        "type": "text",
        "text": "hello"
    }]
}

# %%
print(message)
# Out:
# {'role': 'user', 'content': [{'type': 'text', 'text': 'hello'}]}

# %%
messages.append(message)

print(messages)
# Out:
# [{'role': 'user', 'content': [{'type': 'text', 'text': 'hello'}]}]

# %%
reply_message = {
    "role": "assistant",
    "content":[{
        "type": "text",
        "text": "hi"
    }]
}

# %%
messages.append(reply_message)
print(messages)
# Out:
# [{'role': 'user', 'content': [{'type': 'text', 'text': 'hello'}]}, {'role': 'assistant', 'content': [{'type': 'text', 'text': 'hi'}]}]

# %%
print(messages[1]["content"][0]["text"])
# Out:
# hi

# %%
print(messages[0]["content"][0]["text"])
# Out:
# hello

# %%
print(messages[0]["role"])
# Out:
# user

# %%
print(messages[1]["content"][0]["text"])
print(messages[1]["role"])
# Out:
# hi
# assistant

# %%
for item in messages:
    print(item["role"])
    print(item["content"][0]["text"])
# Out:
# user
# hello
# assistant
# hi

# %%
from datetime import datetime


user = 0
assistant = 0
user_text = []
assistant_text =[]

i = 0;
for item in messages:
    if item["role"] == "user":
        user = user +1
        user_text.append(item)
    elif item["role"] == "assistant":
        assistant = assistant +1
        assistant_text.append(item)

    print(item["role"] + ": "+ item["content"][0]["text"])
    print(user)
    print(assistant)

for msg in user_text:
    print(msg["content"][0]["text"])

for c in assistant_text:

    i = i+1
    a = datetime.now()
    print(str(i) + str(a) +  c["content"][0]["text"] )
# Out:
# user: hello
# 1
# 0
# assistant: hi
# 1
# 1
# hello
# 12025-09-27 03:56:48.519578hi
